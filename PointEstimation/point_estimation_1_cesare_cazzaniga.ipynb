# %%
from scipy import optimize
import numpy as np
import matplotlib.pyplot as plt

# %%
# Poisson pdf
def poisson(n, mu):
    # can the following functions: pow(x,y), np.exp(x), np.math.factorial(n)
    ans = np.exp(-mu)*pow(mu,n)/np.math.factorial(n)
    return ans

# 1. likelihood
def lh(D, Q, s, b, k):
    # protection to stay within physical range
    if (D<=0 or Q<=0 or s+b<0 or b*k<0):
        return 0
    return poisson(D,s+b) * poisson(Q,k*b)

# -2 * log(likelihood)
def lnlh(D, Q, s, b, k):
    l = lh(D, Q, s, b, k)
    if (l<=0):
        return 1e99
    return -2*np.log(l)

# the following "wrappers" are need to call scipy.optimize.fmin
#  which minimises a function w.r.t. its first parameter
# likelihood as a function of b (s is a parameter)
def lh_b(x,*args):
    b = x[0]
    s = args[3]
    D = args[0]
    Q = args[1]
    k = args[2]
    return lh(D,Q,s,b,k)

# -2 * log(likelihood) as a function of b (s is a parameter)
def lnlh_b(x,*args):
    b = x[0]
    s = args[3]
    D = args[0]
    Q = args[1]
    k = args[2]
    return lnlh(D,Q,s,b,k)

# %%
# 2. draw the profile likelihood

# parameters
D = 13
B = 2.6
dB = 0.7

# derived quantities
Q = int((B/dB)**2)
k = B/(dB**2)

# arrays for plotting:
# scan of s values
s_vals = np.linspace(0,20,100)
# corresponding log(likelihood) values
lh_vals = []

# corresponding profile log(likelihood) values
proflh_vals = []


# global minimum (ML estimates): \hat{b} and \hat{s}
bhat = Q/k 
print 'bhat: ', bhat
shat = D - bhat 
print 'shat: ', shat
# maximum likelihood value
lhmax = lh(D, Q, shat, bhat, k)
print 'max likelihood:', lhmax
# minimum -2*log(likelihood) value
lnlhmin = lnlh(D, Q, shat, bhat, k)
print 'min  log-likelihood:', lnlhmin 
print '*************************************' 
# fill the arrays
for s in s_vals:
    # find the MLE for b, with s fixed to a given value.
    # you can use this minimiser: https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.fmin.html
    
    bhathat =  optimize.fmin(lnlh_b, D - B, (D,Q,k,s))
    # fmin returns a bunch of stuff. We are only interested in the value of the parameter which minimises the function.
    bhathat = bhathat[0]
    
    # fill the likelihood value (with b set to the MLE bhat)
    lh_vals.append(lnlh(D, Q, s, bhat, k) - lnlhmin) 
    
    # fill the profile likelihood value
    proflh_vals.append(lnlh(D, Q, s, bhathat, k) - lnlhmin)

# plotting
fix, ax = plt.subplots()
ax.plot(s_vals, lh_vals, label='Likelihood (best fit $\hat{b}$)')
ax.plot(s_vals, proflh_vals, label='Profile likelihood')
ax.set_xlabel('s')
ax.set_ylabel('$-2 \Delta \ln \mathcal{L}$')
ax.set_ybound(0,10)
ax.legend()
plt.show()
# Out:
# bhat:  2.45
# shat:  10.55
# max likelihood: 0.012086762756975082
# min  log-likelihood: 8.831288824493782
# *************************************
# Optimization terminated successfully.
#          Current function value: 25.156332
#          Iterations: 19
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 24.302009
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 23.478832
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 22.686634
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 21.925143
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 21.193983
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 20.492690
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 19.820714
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 19.177436
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 18.562174
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 17.974198
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 17.412742
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 16.877009
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 16.366187
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 15.879454
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 15.415984
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 14.974960
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 14.555571
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 14.157024
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 13.778542
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 13.419370
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 13.078776
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.756051
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.450514
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.161506
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.888399
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.630586
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.387488
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.158552
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.943248
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.741068
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.551529
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.374171
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.208552
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.054251
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.910868
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.778020
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.655341
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.542482
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.439111
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.344909
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.259573
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.182813
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.114351
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.053923
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.001274
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.956162
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.918356
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.887632
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.863779
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.846591
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.835874
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.831439
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.833108
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.840707
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.854071
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.873040
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.897462
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.927189
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 8.962080
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.001999
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.046814
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.096401
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.150636
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.209405
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.272592
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.340090
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.411794
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.487603
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.567418
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.651146
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.738695
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.829977
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 9.924907
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.023403
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.125384
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.230774
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.339498
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.451484
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.566663
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.684965
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.806325
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 10.930681
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.057969
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.188131
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.321108
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.456843
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.595282
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.736371
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 11.880060
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.026298
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.175036
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.326226
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.479823
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.635782
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.794060
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 12.954613
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 13.117401
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 13.282383
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 13.449521
#          Iterations: 20
#          Function evaluations: 40

# %%
# 3. marginalisation

# define priors
def prior_flat_positive(x):
    # a flat prior, restricted to x>0
    if x > 0.  :
        return 1.
    else:
        return 1e-20

def prior_flat(x):
    # a flat prior defined for both positive and negative values
    return 1.

def prior_Jeffreys(s,b):
    # Jeffreys prior for the Poisson mean, in the presence of background b
    if (s + b) > 0:
        return 1./np.sqrt(s + b)
    else:
        return 1e-20 

# define posteriors using Bayes' theorem (ignoring normalisation) 
def posterior_flatprior(D,Q,s,b,k):
    return lh(D, Q, s, b, k)*prior_flat_positive(s)*prior_flat(b)      

def posterior_Jeffreys(D,Q,s,b,k):
    return lh(D, Q, s, b, k)*prior_Jeffreys(s,0)*prior_flat(b) 

def posterior_Jeffreys_b(D,Q,s,b,k):
     return lh(D, Q, s, b, k)*prior_Jeffreys(s,b)*prior_flat(b)

# MCMC: Metropolis-Hastings algorithm
# inputs: 
# - fun: function
# - n: number of iterations
# - D, Q, k: inputs of the problem
# - s0, b0: starting point
# output:
# - (vs,bs) where vs and bs are arrays containing all the successive values for s and b
def mcmc(fun, n, D,Q,s0,b0,k):
    vs = [s0,]
    vb = [b0,]

    # some naive guess of what the variance of s and b could roughly be
    sigmas = max(1,2.*np.sqrt(s0))
    sigmab = max(1,2.*np.sqrt(b0))

    for i in range(0,n):     
        
        # 1. generate a value \vec{\theta} (= (s,b) in our case) using the proposal density q(theta, theta_0)
        # (we can take q as a Gaussian with mean (s0,b0) and std. dev. (sigmas, sigmab))
        # using https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
        
        #s1 = np.random.normal(s0, sigmas)
        #b1 = np.random.normal(b0, sigmab)
        
        mean = [s0 , b0]
        cov = [[sigmas,0.],[0.,sigmab]]
        
        (s, b) = np.random.multivariate_normal(mean, cov) #theta
        
        
        # 2. Form the Hastings test ratio
        
        if fun(D,Q,s0,b0,k) != 0:
            alpha = min(1.,fun(D,Q,s,b,k)/fun(D,Q,s0,b0,k))
            #print alpha
        else:
            alpha = 0.
        
        
        # 3. Generate u uniformly in [0,1]
        # using https://numpy.org/doc/stable/reference/random/generated/numpy.random.random.html
        
        u = np.random.uniform(0., 1.) 
        
        # 4. If u <= alpha, theta1 = theta; otherwise, theta_1 = theta_0
        
        if (u <= alpha):
            
            s1 = s
            b1 = b
            
        else:
            
            s1 = s0
            b1 = b0
            
        if (i > 2000): # burn-in: ignore the first iterations
            
            vs.append(s1)
            vb.append(b1)
        
        # 5. Set theta_0 = theta_1 and go back to step 1
        
        s0 = s1
        b0 = b1
  

    return (vs,vb)

# %%
# number of iterations for MCMC. 100000 takes a few seconds on an i7
niter_mcmc = 100000
n_iter = list(range(0, 98000))

# %%
# 3.a flat prior
vals_flat = mcmc(posterior_flatprior, niter_mcmc, D, Q, shat, bhat, k)

# plotting
fig, ax = plt.subplots()
ax.plot(vals_flat[0], vals_flat[1],color='tab:blue' )
ax.set_xlabel('s')
ax.set_ylabel('b')
ax.set_title('Flat prior')

fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].plot(n_iter, vals_flat[0], color='tab:blue')
#axs[1, 0].plot(n_iter, vals_flat[1], color='r')
axs[1].hist(vals_flat[0], histtype='step', color='tab:blue')
#axs[1, 1].hist(vals_flat[1], color='r')

axs[0].set_xlabel('#iteration')
axs[0].set_ylabel('s')

#axs[1, 0].set_xlabel('#iteration')
#axs[1, 0].set_ylabel('b')

axs[1].set_xlabel('s')
#axs[1, 1].set_xlabel('b')

plt.show()

# %%
# 3.b Jeffreys prior (b=0)
vals_Jeffreys = mcmc(posterior_Jeffreys, niter_mcmc, D, Q, shat, bhat, k)

# plotting
fig, ax = plt.subplots()
ax.plot(vals_Jeffreys[0], vals_Jeffreys[1], color='tab:orange')
ax.set_xlabel('s')
ax.set_ylabel('b')
ax.set_title('Jeffrey prior (b=0)')

n_iter = list(range(0, 98000))
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].plot(n_iter, vals_Jeffreys[0], color='tab:orange')
#axs[1, 0].plot(n_iter, vals_Jeffreys[1], color='r')
axs[1].hist(vals_Jeffreys[0], histtype='step' ,color='tab:orange')
#axs[1, 1].hist(vals_Jeffreys[1], color='r')

axs[0].set_xlabel('#iteration')
axs[0].set_ylabel('s')

#axs[1, 0].set_xlabel('#iteration')
#axs[1, 0].set_ylabel('b')

axs[1].set_xlabel('s')
#axs[1, 1].set_xlabel('b')

plt.show()

# %%
# 3.c Jeffreys prior (b=bhat)
vals_Jeffreys_b = mcmc(posterior_Jeffreys_b, niter_mcmc, D, Q, shat, bhat, k)

# plotting
fig, ax = plt.subplots()
ax.plot(vals_Jeffreys_b[0], vals_Jeffreys_b[1], color='tab:green')
ax.set_xlabel('s')
ax.set_ylabel('b')

ax.set_title('Jeffrey prior (b!=0)')

n_iter = list(range(0, 98000))
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].plot(n_iter, vals_Jeffreys_b[0], color='tab:green')
#axs[1, 0].plot(n_iter, vals_Jeffreys_b[1], color='r')
axs[1].hist(vals_Jeffreys_b[0], histtype='step', color='tab:green')
#axs[1, 1].hist(vals_Jeffreys_b[1], color='r')

axs[0].set_xlabel('#iteration')
axs[0].set_ylabel('s')

#axs[1, 0].set_xlabel('#iteration')
#axs[1, 0].set_ylabel('b')

axs[1].set_xlabel('s')
#axs[1, 1].set_xlabel('b')


plt.show()

# %%
# compare the marginalised posteriors
bins = np.linspace(0,30,60)

#plotting
fix, ax = plt.subplots()
ax.hist(vals_flat[0], bins, 
        density=True, label='Flat prior', histtype='step')
ax.hist(vals_Jeffreys[0], bins,
        density=True, label='Jeffreys prior ($b=0$)', histtype='step')
ax.hist(vals_Jeffreys_b[0], bins, 
        density=True, label='Jeffreys prior ($b=\hat{b}$)', histtype='step')
ax.set_xlabel('s')
ax.legend()
plt.show()

# print
print("For s:")
print("Flat prior: mean = %.2f, median = %.2f, std. dev. = %.2f" % 
      (np.mean(vals_flat[0]), np.median(vals_flat[0]), np.std(vals_flat[0])))
print("Jeffreys prior (b=0): mean = %.2f, median = %.2f, std. dev. = %.2f" % 
      (np.mean(vals_Jeffreys[0]), np.median(vals_Jeffreys[0]), np.std(vals_Jeffreys[0])))
print("Jeffreys prior (b=bhat): mean = %.2f, median = %.2f, std. dev. = %.2f" % 
      (np.mean(vals_Jeffreys_b[0]), np.median(vals_Jeffreys_b[0]), np.std(vals_Jeffreys_b[0])))
print("\nFor b:")
print("Flat prior: mean = %.2f, median = %.2f, std. dev. = %.2f" % 
      (np.mean(vals_flat[1]), np.median(vals_flat[1]), np.std(vals_flat[1])))
print("Jeffreys prior (b=0): mean = %.2f, median = %.2f, std. dev. = %.2f" % 
      (np.mean(vals_Jeffreys[1]), np.median(vals_Jeffreys[1]), np.std(vals_Jeffreys[1])))
print("Jeffreys prior (b=bhat): mean = %.2f, median = %.2f, std. dev. = %.2f" % 
      (np.mean(vals_Jeffreys_b[1]), np.median(vals_Jeffreys_b[1]), np.std(vals_Jeffreys_b[1])))
print ("\nMLE: shat = %f, bhat = %f" % (shat, bhat))
# Out:
# For s:
# Flat prior: mean = 11.45, median = 11.08, std. dev. = 3.87
# Jeffreys prior (b=0): mean = 10.67, median = 10.35, std. dev. = 3.76
# Jeffreys prior (b=bhat): mean = 10.85, median = 10.57, std. dev. = 3.69
#
# For b:
# Flat prior: mean = 2.63, median = 2.57, std. dev. = 0.71
# Jeffreys prior (b=0): mean = 2.67, median = 2.60, std. dev. = 0.72
# Jeffreys prior (b=bhat): mean = 2.63, median = 2.57, std. dev. = 0.70
#
# MLE: shat = 10.550000, bhat = 2.450000
